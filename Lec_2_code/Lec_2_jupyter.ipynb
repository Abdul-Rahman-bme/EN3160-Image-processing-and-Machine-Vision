# %% [markdown]
# ## Lecture 2 Point Operations

# %%
import numpy as np
import matplotlib.pyplot as plt

im = np.zeros((6,8), dtype=np.uint8) # unit8 = 0-255, unsigned integers of 8 bits
im[2,3]=255

fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(6,4))
ax.imshow(im, cmap='gray', vmin=0, vmax=255)
ax.xaxis.set_ticks_position('top')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

im = np.zeros((6,8,3), dtype=np.uint8) # unit8 = 0-255, unsigned integers of 8 bits
im[2,3]=[255,190,203] # red pixel
fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(6,4))
ax.imshow(im)
ax.xaxis.set_ticks_position('top')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

im = cv.imread('D:/Abdul Rahman/Engineering_UOM/.Sem 5/EN3160 - Image Processing and Computer Vision/Lec_2_vscode/emma.jpg')
assert im is not None, "file could not be read, check with os.path.exists()"

fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(6,4))
ax.imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
ax.xaxis.set_ticks_position('top')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

im1 = cv.imread('D:/Abdul Rahman/Engineering_UOM/.Sem 5/EN3160 - Image Processing and Computer Vision/Lec_2_vscode/emma.jpg', cv.IMREAD_GRAYSCALE)
assert im1 is not None, "file could not be read, check with os.path.exists()"
im2=cv.add(im1, 100) # add 100 to all pixels

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(6,4))
ax[0].imshow(cv.cvtColor(im1, cv.COLOR_GRAY2RGB))
ax[0].set_title('Original Image')
ax[1].imshow(cv.cvtColor(im2, cv.COLOR_GRAY2RGB))
ax[1].set_title('Brightened Image')

for a in ax:
    a.axis('off')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

im1 = cv.imread('D:/Abdul Rahman/Engineering_UOM/.Sem 5/EN3160 - Image Processing and Computer Vision/Lec_2_vscode/emma.jpg', cv.IMREAD_GRAYSCALE)
assert im1 is not None, "file could not be read, check with os.path.exists()"
im2=im1+100 # add 100 to all pixels

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(6,4))
ax[0].imshow(cv.cvtColor(im1, cv.COLOR_GRAY2RGB))
ax[0].set_title('Original Image')
ax[1].imshow(cv.cvtColor(im2, cv.COLOR_GRAY2RGB))
ax[1].set_title('Brightened Image')

for a in ax:
    a.axis('off')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

im = cv.imread('D:/Abdul Rahman/Engineering_UOM/.Sem 5/EN3160 - Image Processing and Computer Vision/Lec_2_vscode/emma.jpg')
assert im is not None, "file could not be read, check with os.path.exists()"

im_green=im.copy()
im_green[:,:,0]=0 # set green channel to 0
im_green[:,:,2]=0 # set red channel to 0

im_red=im.copy()
im_red[:,:,0]=0 # set blue channel to 0
im_red[:,:,1]=0 # set green channel to 0

im_blue=im.copy()
im_blue[:,:,1]=0 # set green channel to 0   
im_blue[:,:,2]=0 # set red channel to 0

fig, ax = plt.subplots(nrows=2,ncols=2, figsize=(6,4))
ax[0,0].imshow(cv.cvtColor(im_green, cv.COLOR_BGR2RGB))
ax[0,0].set_title('Green Channel')
ax[0,0].axis('off')

ax[0,1].imshow(cv.cvtColor(im_red, cv.COLOR_BGR2RGB))
ax[0,1].set_title('Red Channel')
ax[0,1].axis('off')

ax[1,0].imshow(cv.cvtColor(im_blue, cv.COLOR_BGR2RGB))
ax[1,0].set_title('Blue Channel')
ax[1,0].axis('off')

ax[1,1].imshow(cv.cvtColor(im, cv.COLOR_BGR2RGB))
ax[1,1].set_title('Original Image')
ax[1,1].axis('off')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

f = cv.imread('D:/Abdul Rahman/Engineering_UOM/.Sem 5/EN3160 - Image Processing and Computer Vision/Lec_2_vscode/emma.jpg')
assert f is not None, "file could not be read, check with os.path.exists()"

t = np.arange(256, dtype=np.uint8)  # Identity transformation

fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(12,4))
ax.plot(t, color='black')
ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_xlabel('Input Intensity')
ax.set_ylabel('Output Intensity')
ax.set_title('Identity Transformation')
plt.show()

fig, ax = plt.subplots(nrows=1,ncols=3, figsize=(12,4))

ax[0].imshow(f, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('Original Image')
ax[0].axis('off')

ax[1].imshow(t, t, color='black')
ax[1].set_title('Transformed Image')
ax[1].axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 25
#      21 ax[0].imshow(f, cmap='gray', vmin=0, vmax=255)
#      22 ax[0].set_title('Original Image')
#      23 ax[0].axis('off')
#      24
# ---> 25 ax[1].imshow(t, t, color='black')
#      26 ax[1].set_title('Transformed Image')
#      27 ax[1].axis('off')
#      28
#
#     [... skipping hidden 1 frame]
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\axes\_axes.py:6363, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    6145 @_preprocess_data()
#    6146 @_docstring.interpd
#    6147 def imshow(self, X, cmap=None, norm=None, *, aspect=None,
#    (...)   6150            interpolation_stage=None, filternorm=True, filterrad=4.0,
#    6151            resample=None, url=None, **kwargs):
#    6152     """
#    6153     Display data as an image, i.e., on a 2D regular raster.
#    6154
#    (...)   6361     (unassociated) alpha representation.
#    6362     """
# -> 6363     im = mimage.AxesImage(self, cmap=cmap, norm=norm, colorizer=colorizer,
#    6364                           interpolation=interpolation, origin=origin,
#    6365                           extent=extent, filternorm=filternorm,
#    6366                           filterrad=filterrad, resample=resample,
#    6367                           interpolation_stage=interpolation_stage,
#    6368                           **kwargs)
#    6370     if aspect is None and not (
#    6371             im.is_transform_set()
#    6372             and not im.get_transform().contains_branch(self.transData)):
#    6373         aspect = mpl.rcParams['image.aspect']
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\image.py:908, in AxesImage.__init__(self, ax, cmap, norm, colorizer, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     891 def __init__(self, ax,
#     892              *,
#     893              cmap=None,
#    (...)    903              **kwargs
#     904              ):
#     906     self._extent = extent
# --> 908     super().__init__(
#     909         ax,
#     910         cmap=cmap,
#     911         norm=norm,
#     912         colorizer=colorizer,
#     913         interpolation=interpolation,
#     914         origin=origin,
#     915         filternorm=filternorm,
#     916         filterrad=filterrad,
#     917         resample=resample,
#     918         interpolation_stage=interpolation_stage,
#     919         **kwargs
#     920     )
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\image.py:277, in _ImageBase.__init__(self, ax, cmap, norm, colorizer, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     264 def __init__(self, ax,
#     265              cmap=None,
#     266              norm=None,
#    (...)    275              **kwargs
#     276              ):
# --> 277     super().__init__(self._get_colorizer(cmap, norm, colorizer))
#     278     origin = mpl._val_or_rc(origin, 'image.origin')
#     279     _api.check_in_list(["upper", "lower"], origin=origin)
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\colorizer.py:629, in _ScalarMappable._get_colorizer(cmap, norm, colorizer)
#     625     _ScalarMappable._check_exclusionary_keywords(
#     626         Colorizer, cmap=cmap, norm=norm
#     627     )
#     628     return colorizer
# --> 629 return Colorizer(cmap, norm)
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\colorizer.py:56, in Colorizer.__init__(self, cmap, norm)
#      53 def __init__(self, cmap=None, norm=None):
#      55     self._cmap = None
# ---> 56     self._set_cmap(cmap)
#      58     self._id_norm = None
#      59     self._norm = None
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\colorizer.py:223, in Colorizer._set_cmap(self, cmap)
#     215 """
#     216 Set the colormap for luminance data.
#     217
#    (...)    220 cmap : `.Colormap` or str or None
#     221 """
#     222 in_init = self._cmap is None
# --> 223 cmap_obj = _ensure_cmap(cmap, accept_multivariate=True)
#     224 if not in_init and self.norm.n_components != cmap_obj.n_variates:
#     225     raise ValueError(f"The colormap {cmap} does not support "
#     226                      f"{self.norm.n_components} variates as required by "
#     227                      f"the {type(self.norm)} on this Colorizer")
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\colorizer.py:823, in _ensure_cmap(cmap, accept_multivariate)
#     820 cmap_name = mpl._val_or_rc(cmap, "image.cmap")
#     822 for mapping in mappings:
# --> 823     if cmap_name in mapping:
#     824         return mapping[cmap_name]
#     826 # this error message is a variant of _api.check_in_list but gives
#     827 # additional hints as to how to access multivariate colormaps
#
# File <frozen _collections_abc>:781, in Mapping.__contains__(self, key)
#     778 'Could not get source, probably due dynamically evaluated source code.'
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\cm.py:95, in ColormapRegistry.__getitem__(self, item)
#      94 def __getitem__(self, item):
# ---> 95     cmap = _api.getitem_checked(self._cmaps, colormap=item, _error_cls=KeyError)
#      96     return cmap.copy()
#
# File d:\Abdul Rahman\Engineering_UOM\.Sem 5\EN3160 - Image Processing and Computer Vision\Lec_2_vscode\.venv\Lib\site-packages\matplotlib\_api\__init__.py:284, in getitem_checked(mapping, _error_cls, **kwargs)
#     282 (k, v), = kwargs.items()
#     283 try:
# --> 284     return mapping[v]
#     285 except KeyError:
#     286     raise _error_cls(list_suggestion_error_msg(k, v, mapping.keys())) from None
#
# TypeError: unhashable type: 'numpy.ndarray'
